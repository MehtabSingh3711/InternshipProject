# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MBA Tech Campaign performance.csv')
df.head()
# Out:
#         dates         campaign_id                    campaign_name  \
# 0  30-09-2024           295024176  MBATech_FT&CS_Lead-Gen-2_150324
# 1  05-11-2024  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 2  05-11-2024  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 3  19-10-2024           295014746  MBATech_AL&AI_Lead-Gen-2_150324
# 4  21-10-2024           295054696  MBATech_DP&PM_Lead-Gen-3_150324
#
#   campaign_start_date                 creative_name               ad_id  \
# 0           15-Mar-24       MBATech_Static-4_Salary           392278996
# 1                 NaN  Regula_VS_Tech_Static_240924  120212341312480229
# 2                 NaN          1.2_Cr_Static_200924  120212285781150229
# 3           15-Mar-24       MBATech_Static-4_Salary           392279606
# 4           15-Mar-24          MBATech_Static-5_Job           392298726
#
#   total_spent impressions clicks click_through_rate  ...  years_of_experience  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dates                6178 non-null   object
#  1   campaign_id          6178 non-null   int64
#  2   campaign_name        6178 non-null   object
#  3   campaign_start_date  1390 non-null   object
#  4   creative_name        6178 non-null   object
#  5   ad_id                6178 non-null   int64
#  6   total_spent          6178 non-null   object
#  7   impressions          6178 non-null   object
#  8   clicks               5604 non-null   object
#  9   click_through_rate   6178 non-null   object
#  10  leads                4292 non-null   float64
#  11  platform             6178 non-null   object
#  12  ad_set_name          4508 non-null   object
#  13  ad_set_id            4508 non-null   float64
#  14  years_of_experience  0 non-null      float64
# ...

# %%
df.drop(df.columns[14:24],axis = 1,inplace=True)

# %%
print("DataFrame Information:")
display(df.info())
print("Shape of the DataFrame:")
display(df.shape)
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dates                6178 non-null   object
#  1   campaign_id          6178 non-null   int64
#  2   campaign_name        6178 non-null   object
#  3   campaign_start_date  1390 non-null   object
#  4   creative_name        6178 non-null   object
#  5   ad_id                6178 non-null   int64
#  6   total_spent          6178 non-null   object
#  7   impressions          6178 non-null   object
#  8   clicks               5604 non-null   object
#  9   click_through_rate   6178 non-null   object
#  10  leads                4292 non-null   float64
#  11  platform             6178 non-null   object
#  12  ad_set_name          4508 non-null   object
#  13  ad_set_id            4508 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# ...

# %%
df.head()
# Out:
#         dates         campaign_id                    campaign_name  \
# 0  30-09-2024           295024176  MBATech_FT&CS_Lead-Gen-2_150324
# 1  05-11-2024  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 2  05-11-2024  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 3  19-10-2024           295014746  MBATech_AL&AI_Lead-Gen-2_150324
# 4  21-10-2024           295054696  MBATech_DP&PM_Lead-Gen-3_150324
#
#   campaign_start_date                 creative_name               ad_id  \
# 0           15-Mar-24       MBATech_Static-4_Salary           392278996
# 1                 NaN  Regula_VS_Tech_Static_240924  120212341312480229
# 2                 NaN          1.2_Cr_Static_200924  120212285781150229
# 3           15-Mar-24       MBATech_Static-4_Salary           392279606
# 4           15-Mar-24          MBATech_Static-5_Job           392298726
#
#   total_spent impressions clicks click_through_rate  leads  platform  \
# ...

# %%
df['dates'] = pd.to_datetime(df['dates'], errors='coerce',dayfirst=True)
df['campaign_start_date'] = pd.to_datetime(df['campaign_start_date'], errors='coerce',dayfirst=True)
# Out:
# C:\Users\mehta\AppData\Local\Temp\ipykernel_19836\3127046381.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['campaign_start_date'] = pd.to_datetime(df['campaign_start_date'], errors='coerce',dayfirst=True)

# %%
df['total_spent'] = df['total_spent'].replace({',': ''}, regex=True).astype(float)
df['impressions'] = df['impressions'].replace({',': ''}, regex=True).astype('Int64')
df['clicks'] = df['clicks'].replace({',': ''}, regex=True).astype('Int64')

# %%
df['click_through_rate'] = df['click_through_rate'].replace({'%': ''}, regex=True).astype(float)

# %%
df['ad_set_id'] = df['ad_set_id'].astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dates                6178 non-null   datetime64[ns]
#  1   campaign_id          6178 non-null   int64
#  2   campaign_name        6178 non-null   object
#  3   campaign_start_date  1390 non-null   datetime64[ns]
#  4   creative_name        6178 non-null   object
#  5   ad_id                6178 non-null   int64
#  6   total_spent          6178 non-null   float64
#  7   impressions          6178 non-null   Int64
#  8   clicks               5604 non-null   Int64
#  9   click_through_rate   6178 non-null   float64
#  10  leads                4292 non-null   float64
#  11  platform             6178 non-null   object
#  12  ad_set_name          4508 non-null   object
#  13  ad_set_id            4508 non-null   Int64
# ...

# %%
df.head(10)
# Out:
#        dates         campaign_id                    campaign_name  \
# 0 2024-09-30           295024176  MBATech_FT&CS_Lead-Gen-2_150324
# 1 2024-11-05  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 2 2024-11-05  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 3 2024-10-19           295014746  MBATech_AL&AI_Lead-Gen-2_150324
# 4 2024-10-21           295054696  MBATech_DP&PM_Lead-Gen-3_150324
# 5 2024-10-25           295054696  MBATech_DP&PM_Lead-Gen-3_150324
# 6 2024-10-15           295054696  MBATech_DP&PM_Lead-Gen-3_150324
# 7 2024-11-05  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 8 2024-11-05  120212285593820229   MBA_Tech_C-2_Lead_Gen-2_210924
# 9 2024-10-24           295054696  MBATech_DP&PM_Lead-Gen-3_150324
#
#   campaign_start_date                         creative_name  \
# 0          2024-03-15               MBATech_Static-4_Salary
# 1                 NaT          Regula_VS_Tech_Static_240924
# ...

# %% [markdown]
# #### PERCENTAGE OF NULL VALUES

# %%
df.isnull().sum()/df.shape[0] * 100
# Out:
# dates                   0.000000
# campaign_id             0.000000
# campaign_name           0.000000
# campaign_start_date    77.500809
# creative_name           0.000000
# ad_id                   0.000000
# total_spent             0.000000
# impressions             0.000000
# clicks                  9.291033
# click_through_rate      0.000000
# leads                  30.527679
# platform                0.000000
# ad_set_name            27.031402
# ad_set_id              27.031402
# dtype: float64
