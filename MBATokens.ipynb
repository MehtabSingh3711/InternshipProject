# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('MBA Tokens.csv')

# %%
df
# Out:
#    candidate_id       candidate_name       Phone                        Email  \
# 0           NaN   Alok Singh Rathore  8197875911   aloksinghrathore@gmail.com
# 1   DELX-379891          Amit Munjal  9811117110         amitmunjal@gmail.com
# 2   DELX-237805       Kanika Gussain  9711911111      kanikagussain@gmail.com
# 3   DELX-230782        Shubham Bisht  7610111198       shubhambisht@gmail.com
# 4           NaN   Gauri Shankar Soni  8101011610   gaurishankarsoni@gmail.com
# ..          ...                  ...         ...                          ...
# 80  DELX-259001          Hari Prasad  9176171750         hariprasad@gmail.com
# 81  BLRX-163381   Amberisch Gawaskar  7718006665  amberischgawaskar@gmail.com
# 82  DELX-350024           Gaurav Das  8711071111          gauravdas@gmail.com
# 83  DELX-193394  Qazi Syed Wamiq Ali  7860997761   qazisyedwamiqali@gmail.com
# 84          NaN       Keshav Agarwal  9951111711      keshavagarwal@gmail.com
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   candidate_id           33 non-null     object
#  1   candidate_name         85 non-null     object
#  2   Phone                  85 non-null     int64
#  3   Email                  85 non-null     object
#  4   agent                  85 non-null     object
#  5   token_date             85 non-null     object
#  6   token_paid             85 non-null     int64
#  7   token_status           85 non-null     object
#  8   lead_source            85 non-null     object
#  9   remarks                0 non-null      float64
#  10  lead_created_date      82 non-null     object
#  11  full_payment_date      58 non-null     object
#  12  Enrolled               58 non-null     object
#  13  offer_letter_released  85 non-null     int64
# ...

# %%
df.drop(columns=['remarks','interview','offer_released_date','loan_oneshot','loan_docs'],inplace = True)
